# %%
from preprocessing import *
import numpy as np
import matplotlib.pyplot as plt

# %%
path = './Data/In-lab/P2/'

data = get_data(path)

# %%
interval_to_show = (0, 250)
plt.plot(np.arange(*interval_to_show), data[0, interval_to_show[0]:interval_to_show[1]])
plt.show()
